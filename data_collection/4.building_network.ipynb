# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # Building network

# %%
df = pd.read_csv('./data/dataset_sentiment.csv', 
                 converters={"Links": lambda x: x.strip("[]").replace("'","").split(", ")}) # from str to list
df = df[['Page', 'Category', 'Links', 'Text', 'Score']]

df.head()
# Out:
#                                           Page   Category  \
# 0                                   Field trip  Education
# 1  Education in emergencies and conflict areas  Education
# 2                             Ability grouping  Education
# 3                      Classwide Peer Tutoring  Education
# 4                            Flexible learning  Education
#
#                                                Links  \
# 0  [American Association of School Administrators...
# 1  [Adult, Armed conflict, Asylum seeker, Banglad...
# 2  [Academic achievement, Classroom, Cluster grou...
# 3  [ADHD, Active learning, Cardio-pulmonary resus...
# 4  [Australia, Blended learning, Distance educati...
#
#                                                 Text   Score
# 0  ['A field trip or excursion is a journey by a ...  0.9837
# 1  ["Education in emergencies and conflict areas ... -0.9356
# 2  ['Ability grouping is the educational practice...  0.9931
# 3  ['Classwide Peer Tutoring (CWPT) is a variatio...  0.9960
# 4  ['Flexible learning is a principle of practice...  0.7579

# %%
df.shape
# Out:
# (14928, 5)

# %%
# 'Links' is a list of pages
df.iloc[0,2]
# Out:
# ['American Association of School Administrators',
#  'Amusement parks',
#  'Australia',
#  'Bangladesh',
#  'Businesses',
#  'Calgary Aero-Space Museum',
#  'Calgary Board of Education',
#  'Calgary City Hall',
#  'Calgary Science Centre',
#  'Calgary Stampede',
#  'Calgary Zoo',
#  'Canada Olympic Park',
#  'Charles Darwin',
#  'Chicago',
#  'Community agencies',
#  'Cross Conservation Area',
#  'Curriculum',
#  'Doi (identifier)',
#  'Education',
#  'Education Next',
#  'Education in Japan',
#  'Europe',
#  'Excursion',
#  'Experiential learning',
#  'Factories',
#  'Field Museum of Natural History',
#  'Field trip (disambiguation)',
#  'Fire Training Academy',
#  'Geographical',
#  'Geological',
#  'Glenbow Museum and Archives',
#  'Government agency',
#  'Grand Tour',
#  'Guided tour',
#  'Hospital',
#  'ISSN (identifier)',
#  'Inglewood Bird Sanctuary',
#  'Ireland',
#  'Jay P. Greene',
#  'Kyoto',
#  'Kyoto',
#  'Leaf Group',
#  'Lecture',
#  'Middle school',
#  'Museum education',
#  'Nagasaki',
#  'Nagasaki',
#  'Nara',
#  'Nara',
#  'Natural sciences',
#  'Nature centers',
#  'New Zealand',
#  'Nikko',
#  'Tochigi',
#  'Observation',
#  'Pyongyang',
#  'Randomized controlled trial',
#  'Research',
#  'S2CID (identifier)',
#  'Sakoku',
#  'School Trip',
#  'School bus',
#  'School trip',
#  'Science',
#  'Science museum',
#  'Social Enterprise School',
#  'Student',
#  'Teacher',
#  'Tinker School',
#  'Torbay',
#  'New Zealand',
#  'United Kingdom',
#  'University of Calgary',
#  'Western culture',
#  'Worksheet',
#  'Zoo',
#  'Talk:Field trip',
#  'Wikipedia:Article wizard',
#  'Wikipedia:Citation needed',
#  'Wikipedia:Citing sources',
#  'Wikipedia:No original research',
#  'Wikipedia:Verifiability',
#  'Wikipedia:WikiProject Countering systemic bias',
#  'Help:Authority control',
#  'Help:Maintenance template removal',
#  'Category:Articles that may contain original research from May 2008',
#  'Category:Articles with BNF identifiers',
#  'Category:Articles with BNFdata identifiers',
#  'Category:Articles with GND identifiers',
#  'Category:Articles with J9U identifiers',
#  'Category:Articles with LCCN identifiers',
#  'Category:Articles with NDL identifiers',
#  'Category:Articles with NKC identifiers',
#  'Category:Articles with limited geographic scope from April 2010',
#  'Category:Articles with unsourced statements from December 2007',
#  'Module:Authority control/config']

# %%
pages = df['Page'].to_list()

len(pages)
# Out:
# 14928

# %%
# Removing categories and links to pages not in 'Page'
links_clean = [] # list of lists (rows)

for index,row in df.iterrows():
    links_per_page = []
    for e in row['Links']: 
        if e in pages:  # if the page is in the column 'Page'
            links_per_page.append(e)  # then keep it
    links_clean.append(links_per_page)

# %%
links_clean
# Out:
# [['Curriculum',
#   'Experiential learning',
#   'Government agency',
#   'Lecture',
#   'Middle school',
#   'Student',
#   'Teacher',
#   'Zoo'],
#  ['Asylum seeker',
#   'Child',
#   'Children in the military',
#   'Curriculum',
#   'Human rights',
#   'International human rights law',
#   'International law',
#   'Internet',
#   'Learning',
#   'Non-governmental organization',
#   'Open educational resources',
#   'Parent',
#   'Peacebuilding',
#   'Refugee',
#   'Refugee children',
#   'Right to education',
#   'Secondary school',
#   'Student',
#   'Teacher'],
#  ['Academic achievement',
#   'Gifted education',
#   'Lesson',
#   'Student',
#   'Tracking (education)'],
#  ['Active learning',
#   'Curriculum',
#   'Peer-mediated instruction',
#   'United States Department of Education',
#   'What Works Clearinghouse'],
#  ['Blended learning', 'M-learning', 'Networked learning'],
#  ['ERIC'],
#  [],
#  ['Computer-supported collaborative learning',
#   'Cooperative learning',
#   'Educational technology',
#   'Learning',
#   'Learning by teaching',
#   'Learning theory (education)',
#   'Massive open online course',
#   'Networked learning',
#   'Pedagogy',
#   'Peer mentoring',
#   'Reciprocal teaching'],
#  ['Cultural diversity',
#   'Curriculum',
#   'Higher education',
#   'Juvenile delinquency',
#   'Learning by teaching',
#   'Mentorship',
#   'Minority group',
#   'Multiculturalism',
#   'Peer-mediated instruction',
#   'Peer learning',
#   'Secondary school',
#   'Student financial aid',
#   'Youth mentoring'],
#  ['Active learning',
#   'Cooperative learning',
#   'Educational research',
#   'Higher education',
#   'National Survey of Student Engagement',
#   'Pedagogy',
#   'Reflective practice'],
#  [],
#  ['Pedagogy'],
#  [],
#  ['Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Computer science education',
#   'Continuing education',
#   'Dance education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Human rights education',
#   'Index of education articles',
#   'Kindergarten',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Relationship education',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education'],
#  ['Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Computer science education',
#   'Continuing education',
#   'Dual language',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'Kindergarten',
#   'List of education by subject',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Structured English Immersion',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education'],
#  [],
#  [],
#  ['Adoption',
#   'Child abuse',
#   'Child labour',
#   'Curriculum',
#   'Human rights education',
#   'Ministry of Education (United Kingdom)',
#   'Pedagogy',
#   'Right to education'],
#  ['Classic book',
#   'Education reform',
#   'Military strategy',
#   'Military tactics',
#   'Socratic method',
#   'Trivium'],
#  ['International education', 'Philosophy of education', 'Secondary education'],
#  ['Curriculum',
#   'Domestic violence',
#   'Gender equality',
#   'Human rights',
#   'Media literacy'],
#  ['Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Electronic assessment',
#   'Environmental education',
#   'Female education',
#   'Free education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'International education',
#   'Kindergarten',
#   'Learning',
#   'List of education by subject',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Teacher',
#   'Technology education',
#   'Tertiary education',
#   'University',
#   'Values education',
#   'Visual arts education',
#   'Vocational education'],
#  ['Bilingual education', 'English-medium education'],
#  ['Home economics'],
#  ['Anti-intellectualism',
#   'Democide',
#   'Discrimination in education',
#   'Elitism',
#   'Ethnic penalty',
#   'Fear of children',
#   'Ghetto benches',
#   'Hate crime',
#   'Human rights',
#   'Institutional discrimination',
#   'Jewish quota',
#   'Kinder der Landstrasse',
#   'Lynching',
#   'Multiculturalism',
#   'Nonviolence',
#   'Numerus clausus',
#   'Polyculturalism',
#   'Pregnancy discrimination',
#   'Prisoner abuse',
#   'Religious violence',
#   'Self-determination',
#   'Social exclusion',
#   'Speciesism',
#   'State atheism',
#   'White power music',
#   'Wife selling',
#   'Woke'],
#  ['Composition studies',
#   'Doctor of Ministry',
#   'Doctor of Theology',
#   'Film studies',
#   'Health administration',
#   'Home economics',
#   'Policy analysis',
#   'Psychometrics',
#   'Public administration',
#   'Social work',
#   'Television'],
#  ['Anti-social behaviour', 'Progressive education', 'Training'],
#  ['Center for Advanced Materials'],
#  [],
#  ['Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Computer science education',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'International tourism',
#   'Justice tourism',
#   'Kindergarten',
#   'List of education by subject',
#   'Marketing',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'Tourism minister',
#   'Values education',
#   'Vocational education',
#   'War tourism'],
#  ['Democracy',
#   'Democratic education',
#   'Educational technology',
#   'Human Rights Day',
#   'Peace education',
#   'Progressive education',
#   'Right to education',
#   'Rule of law'],
#  ['Academic discipline'],
#  ['Petroleum', 'Vocational education'],
#  ['Comparative education',
#   'Computer science education',
#   'Early childhood education',
#   'Educational equity',
#   'Educational evaluation',
#   'Educational research',
#   'Educational technology',
#   'Electronic assessment',
#   'Female education',
#   'Free education',
#   'History of education',
#   'Inclusion (education)',
#   'International Primary Curriculum',
#   'International student',
#   'Liberalism',
#   'Lifelong learning',
#   'Philosophy of education',
#   'Right to education',
#   'Special education',
#   'Technology education',
#   'Visual arts education',
#   'Vocational education'],
#  ['Key Stage 3'],
#  ['Hospitality management studies'],
#  ['Bilingual education'],
#  ['History of education', 'Nature deficit disorder', 'Progressive education'],
#  ['Curriculum',
#   'Education reform',
#   'Higher education',
#   'Ministry of Education (Malaysia)',
#   'Pedagogy',
#   'Project 985',
#   'Secondary education',
#   'Secondary school',
#   'World War II'],
#  ['Curriculum', 'Scheme of work', 'State school', 'Student', 'Teacher'],
#  ['Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Broadcasting of sports events',
#   'Computer science education',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'Kindergarten',
#   'Lack of physical education',
#   'Learning',
#   'List of education by subject',
#   'Martial arts',
#   'Middle school',
#   'Military education and training',
#   'Ministry of sports',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physics education',
#   'Play (activity)',
#   'Politics and sports',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Regulation of sport',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Student',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education'],
#  ['Active learning',
#   'Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Computer science education',
#   'Continuing education',
#   'Early childhood education',
#   'Education Bureau',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'English language',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Harvard Project Physics',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'Kindergarten',
#   'List of education by subject',
#   'List of physics concepts in primary and secondary education curricula',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical Science Study Committee',
#   'Physical education',
#   'Physics First',
#   'Physics education research',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Socratic method',
#   'Special education',
#   'Teaching',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education'],
#  ['Adult education',
#   'Alternative education',
#   'Apprenticeship',
#   'Autodidacticism',
#   'Bilingual education',
#   'Computer science education',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'Kindergarten',
#   'List of education by subject',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education',
#   'World War II'],
#  ['Craft Academy for Excellence in Science and Mathematics',
#   'Curriculum',
#   'Education policy',
#   'Educational research',
#   'Educational technology',
#   'Female education in STEM',
#   'Financial services',
#   'Global labor arbitrage',
#   'Homeland security',
#   'Information technology',
#   'Mathematics education in the United States',
#   'Political science',
#   'STEAM fields',
#   'STEM pipeline',
#   'United States Department of Education',
#   'Women in STEM fields',
#   'World War II'],
#  ['Civics',
#   'Curriculum',
#   'Political science',
#   'United States Department of Education'],
#  ['Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Computer science education',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'Kindergarten',
#   'List of education by subject',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education'],
#  ['Adverse possession',
#   'Capitalization rate',
#   'Effective gross income',
#   'Foreclosure',
#   'Index of real estate articles',
#   'Land law',
#   'Public administration',
#   'Remortgage'],
#  ['Adult education',
#   'Alternative education',
#   'Apprenticeship',
#   'Arts in education',
#   'Arts integration',
#   'Autodidacticism',
#   'Bilingual education',
#   'Computer science education',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Electronic assessment',
#   'Environmental education',
#   'Female education',
#   'Free education',
#   'Further education',
#   'Gifted education',
#   'Globalism',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'International education',
#   'Kindergarten',
#   'List of education by subject',
#   'Middle school',
#   'Military education and training',
#   'New media art',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'United States Department of Education',
#   'Values education',
#   'Vocational education',
#   'World War II'],
#  ['Curriculum'],
#  ['21st century skills',
#   'Active learning',
#   'Animal cognition',
#   'Animal consciousness',
#   'Anthrozoology',
#   'Aptitude',
#   'Augmented learning',
#   'Autodidacticism',
#   'Child development',
#   'Classical conditioning',
#   'Dialogic learning',
#   'E. O. Wilson',
#   'Epigenetics in learning and memory',
#   'Habituation',
#   'Implicit learning',
#   'Imprinting (psychology)',
#   'Instructional theory',
#   'Lifelong learning',
#   'Machine learning',
#   'Meaningful learning',
#   'Media psychology',
#   'Metacognition',
#   'Minimally invasive education',
#   'Observational learning',
#   'Operant conditioning',
#   'Passive learning',
#   'Pedagogy',
#   'Play (activity)',
#   'Psychometrics',
#   'Retraining',
#   'Sensitization',
#   'Skill',
#   'Spatial intelligence (psychology)',
#   'Student-centered learning',
#   'Subgoal labeling',
#   'Teaching',
#   'Theory of multiple intelligences',
#   'Traditional education'],
#  ['Classical conditioning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Psychometrics',
#   'Sensitization',
#   'Spatial intelligence (psychology)',
#   'Theory of multiple intelligences'],
#  ['Active learning',
#   'Applied academics',
#   'Aptitude',
#   'Government agency',
#   'Media literacy',
#   'Pedagogy',
#   'Programme for International Student Assessment',
#   'Progressive education',
#   'Skill',
#   'United States Department of Education'],
#  ['Academic administration',
#   'Appreciative advising',
#   'Curriculum',
#   'Outline of academic disciplines',
#   'Pedagogy'],
#  ['Learning', 'Pedagogy'],
#  ['Parent', 'Teacher'],
#  ['Cognitive load', 'Pedagogy'],
#  ['A Vindication of the Rights of Woman',
#   'Anarchism',
#   'Benjamin Franklin',
#   'Bertrand Russell',
#   'Capital market',
#   'Capitalist state',
#   'Charles II of Spain',
#   'Communism',
#   'Confucius',
#   'Consent of the governed',
#   'Conservative liberalism',
#   'Constitutionalism',
#   'Cornelius Castoriadis',
#   'Criminal justice',
#   'Culture of capitalism',
#   'David Hume',
#   'Democracy',
#   'Divine right of kings',
#   'Economic freedom',
#   'Economic globalization',
#   'Economic liberalism',
#   'Egalitarianism',
#   'Ethical socialism',
#   'Five Eyes',
#   'Frankfurt School',
#   'Freedom of speech',
#   'Friedrich Nietzsche',
#   'Gender equality',
#   'General will',
#   'George Orwell',
#   'H. G. Wells',
#   'Hierarchical organization',
#   'Huguenots',
#   'Human rights',
#   'Immanuel Kant',
#   'International law',
#   'Internet',
#   'Investor',
#   'Jean-Jacques Rousseau',
#   'Johann Wolfgang von Goethe',
#   'John Milton',
#   'Karl Marx',
#   'Karl Popper',
#   'Leo Tolstoy',
#   'Liberalism',
#   'Liberty',
#   'Mahatma Gandhi',
#   'Max Weber',
#   'Media bias',
#   'Meritocracy',
#   'Natural rights and legal rights',
#   'Neoliberalism',
#   'Noam Chomsky',
#   'Nordic Council',
#   'Philosophy of religion',
#   'Pierre-Joseph Proudhon',
#   'Pierre Bayle',
#   'Pirate Party',
#   'Political colour',
#   'Political philosophy',
#   'Popular culture',
#   'Positive liberty',
#   'Prisoner of war',
#   'Progress',
#   'Public sphere',
#   'Radical centrism',
#   'Red flag (politics)',
#   'Reform',
#   'Reformism',
#   'Regulatory capitalism',
#   'René Descartes',
#   'Representative democracy',
#   'Republicanism',
#   'Rule of law',
#   'Secular liberalism',
#   'Secularism',
#   'Slavoj Žižek',
#   'Social contract',
#   'Social democracy',
#   'Social liberalism',
#   'Social services',
#   'State socialism',
#   'Takis Fotopoulos',
#   'Tariq Ali',
#   'Third Way',
#   'Thomas Paine',
#   'Voltaire',
#   'War on terror',
#   'Welfare state',
#   'Whiggism',
#   'World War I',
#   'World War II'],
#  ['Continuing education', 'Curriculum'],
#  ['Audience',
#   'Hierarchy',
#   'Higher education',
#   'Public sector',
#   'Student',
#   'Teacher',
#   'Television',
#   'Textbook'],
#  ['Service-learning'],
#  ['Classical conditioning', 'Learning', 'Observational learning'],
#  ['Instructional design', 'Learning management system'],
#  ['Cognitive load', 'Habituation', 'Learning'],
#  ['Habitus (sociology)'],
#  ['Evaluation', 'Pedagogy'],
#  ['Classical conditioning'],
#  ['Animal cognition',
#   'Blocking effect',
#   'Conditioned emotional response',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Latent inhibition',
#   'Learning',
#   'Machine learning',
#   'Meaningful learning',
#   'Measures of conditioned emotional response',
#   'Observational learning',
#   'Operant conditioning',
#   'Politics of memory',
#   'Preparedness (learning)',
#   'Second-order conditioning',
#   'Sensitization',
#   'Spontaneous recovery'],
#  ['Learning'],
#  ['Active learning',
#   'Block scheduling',
#   'Constructivism (philosophy of education)',
#   'Excellence and equity',
#   'Expertise reversal effect',
#   'Inclusion (education)',
#   'Instructional design',
#   'Instructional materials',
#   'Inventive spelling',
#   'Learning standards',
#   'Lecture',
#   'Metacognition',
#   'Modality effect',
#   'Outcome-based education',
#   'Pedagogy',
#   'Phonics',
#   'Small schools movement',
#   'Split attention effect',
#   'Standard algorithms',
#   'Standardized test',
#   'Tracking (education)',
#   'Traditional education',
#   'Worked-example effect'],
#  ['21st century skills', 'Machine learning'],
#  [],
#  ['Community of practice', 'Public administration', 'René Descartes'],
#  ['Business intelligence',
#   'Community of inquiry',
#   'Community politics',
#   'Distributed leadership',
#   'Imagined community',
#   'Learning',
#   'Legitimate peripheral participation',
#   'Persona (user experience)',
#   'Situated learning',
#   'Social aspects of television',
#   'Social bot',
#   'Social capital',
#   'Social media intelligence',
#   'Social network analysis',
#   'Social web',
#   'Social work',
#   'Viral phenomenon'],
#  ['Blended learning',
#   'Competency architecture',
#   'Educational technology',
#   'Learning management system',
#   'Lifelong learning',
#   'Virtual learning environment'],
#  ['Classical conditioning',
#   'Measures of conditioned emotional response',
#   'Media psychology',
#   'Military psychology',
#   'Noam Chomsky',
#   'Political psychology',
#   'Psychometrics'],
#  ['Classical conditioning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Meaningful learning',
#   'Neutral stimulus',
#   'Observational learning',
#   'Operant conditioning',
#   'Politics of memory',
#   'Sensitization'],
#  ['Aggression',
#   'Attachment in children',
#   'Attachment theory',
#   'Cinderella effect',
#   'Daniel Dennett',
#   'David Hume',
#   'E. O. Wilson',
#   'Fraternal birth order and male sexual orientation',
#   'John Bowlby',
#   'Learning rule',
#   'Machine learning',
#   'Maternal deprivation',
#   'Mind-blindness',
#   'Noam Chomsky',
#   'Sex differences in crime',
#   'Social aspects of television',
#   'Westermarck effect'],
#  ['Design-focused evaluation',
#   'Educational evaluation',
#   'Learning',
#   'Lecture',
#   'Teaching'],
#  ['Child abuse',
#   'Child development',
#   'Connectionism',
#   'European Second Language Association',
#   'Feral child',
#   'Language Testing',
#   'List of common misconceptions about language learning',
#   'Noam Chomsky',
#   'Operant conditioning'],
#  [],
#  ['Curriculum', 'Educational assessment'],
#  ['Learning'],
#  ['Computer-supported collaborative learning',
#   'Cultural imperialism',
#   'Egalitarian dialogue',
#   'Jacques Derrida',
#   'Learning',
#   'Learning theory (education)',
#   'Pedagogy',
#   'Socratic method',
#   'Transformative learning'],
#  ['Blended learning',
#   'Differentiated instruction',
#   'Education and technology',
#   'Educational technology',
#   'Educational technology in sub-Saharan Africa',
#   'Gamification of learning',
#   'Massive open online course',
#   'Online credentials for learning',
#   'Open educational resources'],
#  ['Indigenous peoples'],
#  ['Blocking effect',
#   'Classical conditioning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Psychology of learning',
#   'Sensitization'],
#  ['Classical conditioning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Military psychology',
#   'Observational learning',
#   'Operant conditioning',
#   'Perceptual learning',
#   'Political psychology',
#   'Psychometrics',
#   'Sensitization'],
#  ['Skill'],
#  ['Curriculum',
#   'Dyscalculia',
#   'Dyslexia',
#   'Educational assessment',
#   'Mean world syndrome',
#   'Media bias',
#   'Overton window',
#   'Propaganda'],
#  ['Active learning',
#   'Adult education',
#   'Alternative education',
#   'Alternative school',
#   'Autodidacticism',
#   'Charter school',
#   'Classical education movement',
#   'College',
#   'Comparative education',
#   'Compensatory education',
#   'Compulsory education',
#   'Constructivism (philosophy of education)',
#   'Context-based learning',
#   'Continuing education',
#   'Criticism of schooling',
#   'Curriculum',
#   'Curriculum studies',
#   'Day school',
#   'Democratic education',
#   'Department of Bantu Education',
#   'Early childhood education',
#   'Education policy',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational management',
#   'Educational measurement',
#   'Educational neuroscience',
#   'Educational research',
#   'Educational robotics',
#   'Educational stage',
#   'Educational technology',
#   'Electronic assessment',
#   'Experiential education',
#   'Experiential learning',
#   'Female education',
#   'Free education',
#   'Free school movement',
#   'Further education',
#   'Gifted education',
#   'Hedge school',
#   'Higher education',
#   'History of early childhood care and education',
#   'History of education',
#   'Humanistic education',
#   'Index of education articles',
#   'Indigenous peoples',
#   'Infant school',
#   'Instructional design',
#   'Instructional materials',
#   'Instructional theory',
#   'International education',
#   'Jean-Jacques Rousseau',
#   'Junior school',
#   'Kindergarten',
#   'K–12',
#   'Learning',
#   'Learning by teaching',
#   'Learning theory (education)',
#   'Lesson plan',
#   'List of education by subject',
#   'Middle school',
#   'Montessori education',
#   'National library',
#   'One-room school',
#   'Open classroom',
#   'Open learning',
#   'Oral exam',
#   'Outline of academia',
#   'Outline of educational aims',
#   'Outline of open educational resources',
#   'Parent',
#   'Parenting',
#   'Pedagogy',
#   'Philosophy of education',
#   'Politics in education',
#   'Postgraduate education',
#   'Pre-kindergarten',
#   'Primary school',
#   'Private university',
#   'Progressive education',
#   'Psychometrics',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Service-learning',
#   'Skill',
#   'Slow education',
#   'Sociology of education',
#   'Special education',
#   'Standardized test',
#   'State school',
#   'Student',
#   'Sudbury school',
#   'Teacher',
#   'Teaching credential',
#   'Teaching method',
#   'Technical school',
#   'Tertiary education',
#   'Textbook',
#   'University',
#   'Unschooling',
#   'Vocational education',
#   'Vocational school',
#   'Vocational university'],
#  [],
#  ['Situated learning'],
#  ['Maternal deprivation', 'Perceptual learning'],
#  ['Learning', 'Post-traumatic stress disorder'],
#  ['Discrimination learning', 'Implicit learning', 'Operant conditioning'],
#  ['Classical conditioning'],
#  ['Teaching', 'Teaching method', 'Worked-example effect'],
#  ['Cognitive load',
#   'E-learning (theory)',
#   'Instructional design',
#   'Split attention effect',
#   'Worked-example effect'],
#  ['Appreciative advising', 'College', 'Student orientation', 'University'],
#  ['History of virtual learning environments',
#   'Nordic Council',
#   'Virtual learning environment'],
#  ['Cooperative learning', 'Learning', 'Student', 'Teacher'],
#  ['Assessment for learning',
#   'Digital media',
#   'Educational research',
#   'Entertainment in education',
#   'Gamification of learning'],
#  ['Course (education)', 'Differentiated instruction'],
#  ['Community of practice', 'Graduation', 'Higher education'],
#  ['Classical conditioning',
#   'Dishabituation',
#   'Implicit learning',
#   'Imprinting (psychology)',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Sensitization'],
#  ['Learning', 'Skill'],
#  ['Classical conditioning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Sensitization'],
#  ['Educational assessment',
#   'Learning',
#   'Media psychology',
#   'Military psychology',
#   'Noam Chomsky',
#   'Political psychology',
#   'Psychometrics',
#   'Sequence learning'],
#  ['Attachment theory',
#   'Classical conditioning',
#   'Edvard Westermarck',
#   'Genetic sexual attraction',
#   'Habituation',
#   'Inbreeding',
#   'Incest taboo',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Sensitization',
#   'Westermarck effect'],
#  ['Learning', 'Lifelong learning', 'Study software'],
#  ['Learning', 'Machine learning'],
#  ['Alternative education', 'Autodidacticism', 'Unschooling', 'Youth work'],
#  ['Internet'],
#  ['Inventive spelling', 'Phonics', 'Words in Colour'],
#  ['Learning'],
#  ['Confidence-based learning',
#   'Constructivism (philosophy of education)',
#   'E-learning (theory)',
#   'Educational assessment',
#   'Educational technology',
#   'Electronic portfolio',
#   'Evaluation',
#   'First Principles of Instruction',
#   'Instructional materials',
#   'Instructional theory',
#   'Interdisciplinary teaching',
#   'Learning object',
#   'Lesson study',
#   'Lighting design',
#   'M-learning',
#   'Mind map',
#   'Open educational resources',
#   'Philosophy of design',
#   'STEAM fields',
#   'Training',
#   'Wicked problem',
#   'World War II'],
#  ['Blended learning',
#   'Corporate university',
#   'Educational technology',
#   'Learning',
#   'Lecture',
#   'Self-paced instruction',
#   'Training',
#   'Training and development',
#   'Training management system'],
#  ['Academic dishonesty', 'Autodidacticism', 'Latent inhibition', 'Learning'],
#  ['Metacognition'],
#  ['Learning object metadata'],
#  ['Machine learning'],
#  ['Implicit learning', 'Operant conditioning', 'Psychology of learning'],
#  ['Classical conditioning'],
#  ['Connectionism', 'Operant conditioning'],
#  ['Adaptive hypermedia',
#   'Analytics',
#   'Business intelligence',
#   'Community of practice',
#   'E-learning (theory)',
#   'Educational technology',
#   'Higher education',
#   'Intelligent tutoring system',
#   'Learning management system',
#   'Machine learning',
#   'Massive open online course',
#   'Social network analysis',
#   'Student engagement',
#   'Student information system'],
#  ['Learning', 'Learning power', 'Machine learning', 'Skill'],
#  ['Reflective practice', 'Validated learning'],
#  ['Learning', 'Teaching', 'Training'],
#  ['8 learning management questions',
#   'Asynchronous learning',
#   'Authoring system',
#   'Competency management system',
#   'E-learning (theory)',
#   'Educational technology',
#   'Intelligent tutoring system',
#   'K–12',
#   'Learning object',
#   'Massive open online course',
#   'Open University',
#   'Student information system',
#   'Synchronous learning',
#   'Virtual learning environment'],
#  ['Microlearning', 'Microlecture'],
#  ['Curriculum', 'Electronic portfolio', 'Lesson plan', 'Pedagogy'],
#  ['Learning', 'Lifelong learning'],
#  ['Information technology', 'Sound recording and reproduction'],
#  ['Machine learning'],
#  ['Age segregation in schools',
#   'Educational entertainment',
#   'HighScope',
#   'Kathy Hirsh-Pasek',
#   'Observational learning',
#   'Play (activity)',
#   'Reggio Emilia approach',
#   'Sandpit'],
#  ['Course (education)',
#   'Frontal instruction',
#   'Learning',
#   'Learning by teaching',
#   'Lesson plan',
#   'Music lesson',
#   'Situated learning',
#   'Student',
#   'Teacher',
#   'Textbook',
#   'Virtual learning environment'],
#  ['Adult education',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Computer science education',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'History of education',
#   'Index of education articles',
#   'Kindergarten',
#   'List of education by subject',
#   'Middle school',
#   'Military education and training',
#   'Outline of education',
#   'Peace education',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Sociology of education',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education'],
#  ['Dual-route hypothesis to reading aloud',
#   'Dyslexia',
#   'Educational assessment',
#   'Evaluation',
#   'Independent reading',
#   'Phonics',
#   'Reading disability',
#   'Reading for special needs',
#   'Reciprocal teaching',
#   'Simple view of reading',
#   'Structured Word Inquiry',
#   'Student-centered learning',
#   'Sustained silent reading'],
#  ['Goddard College'],
#  ['Connectionism',
#   'Cyberwarfare',
#   'Discovery (observation)',
#   'Educational technology',
#   'Electronic voting',
#   'Human-in-the-loop',
#   'Information security',
#   'Insurance',
#   'Marketing',
#   'Robot learning',
#   'Training'],
#  [],
#  ['Information technology',
#   'Instructional design',
#   'Learning',
#   'Pedagogy',
#   'Teaching'],
#  ['Active learning',
#   'Concept map',
#   'Integrative learning',
#   'Politics of memory'],
#  ['Classical conditioning',
#   'Conditioned emotional response',
#   'Operant conditioning'],
#  ['Metacognition'],
#  ['Cognitive load', 'Learning nugget', 'Microlecture'],
#  ['Phonics'],
#  ['M-learning'],
#  ['E-learning (theory)', 'Learning'],
#  ['Pieing', 'Play (activity)'],
#  ['Classical conditioning',
#   'Department for Education',
#   'E-learning (theory)',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Institute of Education Sciences',
#   'Learning',
#   'Learning disability',
#   'Observational learning',
#   'Operant conditioning',
#   'Orton-Gillingham',
#   'Sensitization'],
#  ['Situated learning'],
#  ['Service-learning'],
#  ['Asynchronous learning',
#   'Autodidacticism',
#   'Deschooling Society',
#   'Educational technology',
#   'Internet',
#   'Learning',
#   'Massive open online course',
#   'Situated learning',
#   'Social network analysis',
#   'Wikiversity'],
#  ['Classical conditioning'],
#  [],
#  ['Learning'],
#  ['Apprenticeship',
#   'Bobo doll experiment',
#   'Classical conditioning',
#   'Cultural diversity',
#   'Educational technology',
#   'Habituation',
#   'Imitative learning',
#   'Imprinting (psychology)',
#   'Learning',
#   'Machine learning',
#   'Operant conditioning',
#   'Parent',
#   'Sensitization',
#   'Sibling',
#   'Social learning tools',
#   'Teacher'],
#  ['Classical conditioning', 'Law of effect', 'Operant conditioning'],
#  ['Learning'],
#  ['Classical conditioning',
#   'Cognitive load',
#   'Implicit learning',
#   'Learning',
#   'Military psychology',
#   'Political psychology',
#   'Psychometrics'],
#  ['Networked learning'],
#  ['Auditory processing disorder',
#   'Campbell Collaboration',
#   'Cooperative learning',
#   'Curriculum',
#   'Data literacy',
#   'Department for Education',
#   'Department for Education and Skills (United Kingdom)',
#   'Department of Education (Ireland)',
#   'Developmental coordination disorder',
#   'Dual-route hypothesis to reading aloud',
#   'Dyscalculia',
#   'Dysgraphia',
#   'Dyslexia',
#   'Educational technology',
#   'Elkonin boxes',
#   'English language',
#   'Engrish',
#   'Impact of the COVID-19 pandemic on education',
#   'Independent reading',
#   'Initial Teaching Alphabet',
#   'Institute of Education Sciences',
#   'Learning disability',
#   'Literature circle',
#   'Management of dyslexia',
#   'Media literacy',
#   'Multisensory learning',
#   'Namlish',
#   'Non-native pronunciations of English',
#   'Oracy',
#   'Post-literacy',
#   'Programme for International Student Assessment',
#   'Public domain',
#   'Reading disability',
#   'Reading for special needs',
#   'Reciprocal teaching',
#   'Simple view of reading',
#   'Specific developmental disorder',
#   'Structured Word Inquiry',
#   'Sustained silent reading'],
#  ['Adoption',
#   'Ahimsa',
#   'Alloparenting',
#   'Allowance (money)',
#   'Attachment parenting',
#   'Attachment theory',
#   'Bedtime',
#   'Blanket training',
#   'Child',
#   'Child abandonment',
#   'Child abuse',
#   'Child care',
#   'Child custody',
#   'Child development',
#   'Child discipline',
#   'Child labour',
#   'Child support',
#   'Childhood',
#   'Cinderella effect',
#   'Co-sleeping',
#   'Concerted cultivation',
#   'Coparenting',
#   'Corporal punishment in the home',
#   'Cost of raising a child',
#   'Curfew',
#   'Deliberation',
#   'Discipline',
#   'Discovery (observation)',
#   'Disownment',
#   'Faithfulness',
#   'Filial piety',
#   'Foster care',
#   'Free-range parenting',
#   'Gatekeeper parent',
#   'Grounding (discipline technique)',
#   'Helicopter parent',
#   'Impartiality',
#   'Incest',
#   'Jing (philosophy)',
#   'John Bowlby',
#   'Latchkey kid',
#   'Learning',
#   'Learning through play',
#   'Narcissistic parent',
#   'Nurturant parent model',
#   'Orphan',
#   'Parent',
#   'Parental abuse by children',
#   'Parental alienation',
#   'Parenting',
#   'Parenting styles',
#   'Paternity law',
#   'Peace',
#   'Pediatrics',
#   'Pietas',
#   'Play date',
#   'Positive discipline',
#   'Sandpit',
#   'Scholarly method',
#   'Shared parenting',
#   'Single parent',
#   'Slow parenting',
#   'Social aspects of television',
#   'Spoiled child',
#   'Stepfamily',
#   'Strict father model',
#   'Surrogacy',
#   'Taking Children Seriously',
#   'Tiger parenting',
#   'Time-out (parenting)',
#   'Work at home parent'],
#  [],
#  ['Classical conditioning', 'Learning'],
#  ['Active learning', 'Machine learning'],
#  [],
#  ['Adult education',
#   'Classical conditioning',
#   'Constructivism (philosophy of education)',
#   'Experiential learning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Learning curve',
#   'Learning theory (education)',
#   'Lifelong learning',
#   'Media psychology',
#   'Observational learning',
#   'Operant conditioning',
#   'Sensitization',
#   'World War II'],
#  ['Dual-route hypothesis to reading aloud',
#   'Dyslexia',
#   'Independent reading',
#   'Literature circle',
#   'Phonics',
#   'Reading disability',
#   'Reading for special needs',
#   'Reciprocal teaching',
#   'Simple view of reading',
#   'Structured Word Inquiry',
#   'Sustained silent reading'],
#  ['Learning curve', 'Principles of learning', 'Serial-position effect'],
#  ['Educational robotics', 'Machine learning'],
#  ['Play (activity)'],
#  ['Child', 'Miscue analysis', 'Reading Recovery', 'Teacher'],
#  ['Classical conditioning', 'Learning'],
#  ['Criticism of democracy', 'Criticism of science', 'Evaluation'],
#  ['Classical conditioning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Post-traumatic stress disorder'],
#  ['Classical conditioning',
#   'Habituation',
#   'Hierarchical organization',
#   'Implicit learning',
#   'Imprinting (psychology)',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Sensitization',
#   'Skill'],
#  [],
#  ['Implicit learning'],
#  ['Learning curve',
#   'Operant conditioning',
#   'Principles of learning',
#   'Recency bias'],
#  ['Adult education',
#   'Apprenticeship',
#   'Cognitive apprenticeship',
#   'Community of practice',
#   'Constructivism (philosophy of education)',
#   'Digital media',
#   'Digital native',
#   'Educational assessment',
#   'Educational technology',
#   'Experiential learning',
#   'Field trip',
#   'Instructional design',
#   'Intellectual',
#   'Learning',
#   'Legitimate peripheral participation',
#   'Transformative learning'],
#  ['Deskilling', 'Dreyfus model of skill acquisition', 'Learning'],
#  ['Bedtime',
#   'Bedtime story',
#   'Bunk bed',
#   'Comfort object',
#   'Marcel Proust',
#   'Samuel Taylor Coleridge',
#   'Sleep and learning',
#   'Sleepover'],
#  ['Bedtime',
#   'Bedtime story',
#   'Bunk bed',
#   'Comfort object',
#   'Learning',
#   'Sleep-learning',
#   'Sleep and creativity',
#   'Sleepover'],
#  ['Twice exceptional'],
#  ['Socratic method', 'Teaching'],
#  ['Learning', 'Learning curve', 'Skill'],
#  [],
#  ['Cognitive load', 'Expertise reversal effect', 'Worked-example effect'],
#  ['Classical conditioning',
#   'Habituation',
#   'Imprinting (psychology)',
#   'Learning',
#   'Observational learning',
#   'Operant conditioning',
#   'Sensitization'],
#  ['Machine learning'],
#  ['Dual-route hypothesis to reading aloud',
#   'Dyslexia',
#   'Independent reading',
#   'Literature circle',
#   'Phonics',
#   'Reading disability',
#   'Reading for special needs',
#   'Reciprocal teaching',
#   'Simple view of reading',
#   'Sustained silent reading'],
#  ['Educational assessment',
#   'Information security',
#   'Learning management system'],
#  ['Experiential learning',
#   'National Summer Learning Association',
#   'Special education',
#   'Standardized test',
#   'Year-round school in the United States'],
#  ['Phonics'],
#  [],
#  ['Indigenous peoples'],
#  [],
#  [],
#  ['Adult education',
#   'Instructional design',
#   'Lifelong learning',
#   'Mentorship',
#   'Training',
#   'Vocational education'],
#  ['Compliance training',
#   'Educational technology',
#   'Instructor-led training',
#   'Learning management system',
#   'Student information system'],
#  ['Adult education', 'Education Resources Information Center', 'Pedagogy'],
#  ['Compulsory education',
#   'Department for Education',
#   'Form (education)',
#   'Government of the United Kingdom',
#   'Homework coach',
#   'Institute of Education Sciences',
#   'Learning by teaching',
#   'Mentorship',
#   'Peer-mediated instruction',
#   'Secondary school',
#   'Student',
#   'Teacher',
#   'Tutorial system'],
#  ['Learning', 'The DO-IT Center'],
#  [],
#  ['Analytics', 'Learning cycle'],
#  ['English language', 'Learning', 'Phonics'],
#  ['Reciprocal teaching'],
#  ['Animal cognition', 'Animal consciousness', 'Observational learning'],
#  ['Cognitive load',
#   'Example choice',
#   'Expertise reversal effect',
#   'Split attention effect',
#   'Subgoal labeling'],
#  ['Community education',
#   'Informal education',
#   'Student-centered learning',
#   'Student voice',
#   'Youth activism'],
#  [],
#  ['Bullying in teaching',
#   'Certified teacher',
#   'Child abuse',
#   'Civics',
#   'College',
#   'Curriculum',
#   'Devolution',
#   'Differentiated instruction',
#   'Discipline',
#   'ERIC',
#   'Education policy',
#   'History of education',
#   'Internet',
#   'Learning by teaching',
#   'Lecturer',
#   'Lesson plan',
#   'Middle school',
#   'Paraprofessional educator',
#   'Pedagogy',
#   'Primary school',
#   'Secondary education',
#   'Secondary school',
#   'Skill',
#   'Spanking',
#   'Student',
#   'Student teacher',
#   'Study hall',
#   'Teaching',
#   'Tertiary education',
#   'University'],
#  ['Apprenticeship',
#   'Authority',
#   'Educational assessment',
#   'Learning',
#   'Skill',
#   'Student',
#   'Student-centered learning',
#   'Teacher',
#   'Teaching method',
#   'Training'],
# ...
#  [],
#  ['English language', 'Ministry of National Education (Turkey)'],
#  ['Active learning',
#   'Assistive technology',
#   'Bell hooks',
#   'Block scheduling',
#   'Cognitive load',
#   'Constructivism (philosophy of education)',
#   'Curriculum studies',
#   'Differentiated instruction',
#   'Discrimination in education',
#   'Dyslexia',
#   'Educational inequality',
#   'Excellence and equity',
#   'Frankfurt School',
#   'Hidden curriculum',
#   'Inventive spelling',
#   'Learning disability',
#   'Learning standards',
#   'Least dangerous assumption',
#   'Least restrictive environment',
#   'Lecture',
#   'Mainstreaming (education)',
#   'Montessori education',
#   'Multicultural education',
#   'Outcome-based education',
#   'Phonics',
#   'Political consciousness',
#   'Progressive education',
#   'Resource room',
#   'Right to education',
#   'Small schools movement',
#   'Social exclusion',
#   'Special Assistance Program (Australian education)',
#   'Special education',
#   'Special needs',
#   'Speech–language pathology',
#   'Standard algorithms',
#   'Standardized test',
#   'Tracking (education)',
#   'Traditional education',
#   'WeThe15'],
#  [],
#  ['Inclusion (education)', 'Pedagogy', 'Special education'],
#  ['Internet'],
#  ['College', 'Primary school', 'Secondary school', 'World War II'],
#  ['Educational stage', 'Middle school'],
#  ['Education policy', 'Non-governmental organization'],
#  [],
#  ['Doris Kearns Goodwin', 'Robert Reich'],
#  [],
#  ['Ministry of Education (India)',
#   'National Council of Educational Research and Training',
#   'Primary school',
#   'Right to education'],
#  [],
#  [],
#  ['British Library', 'Public lecture'],
#  ['Field trip', 'Primary school'],
#  ['Deaf education', 'Institution', 'Teacher'],
#  [],
#  ['Curriki', 'Qatar National Library'],
#  ['Privatization of public toilets'],
#  ['Alcohol use among college students', 'Higher education'],
#  ['Alternative education',
#   'BlueTrace',
#   'COVID-19 Contact-Confirming Application',
#   'COVIDSafe',
#   'COVID Tracker Ireland',
#   'CareFIJI',
#   'Coronavirus Australia',
#   'Deschooling',
#   'Education Otherwise',
#   'Homeschooling international status and statistics',
#   'Human rights issues related to the COVID-19 pandemic',
#   'Impact of the COVID-19 pandemic on African communities',
#   'Impact of the COVID-19 pandemic on children',
#   'Impact of the COVID-19 pandemic on domestic violence',
#   'Impact of the COVID-19 pandemic on education',
#   'Impact of the COVID-19 pandemic on female education',
#   'Impact of the COVID-19 pandemic on the military',
#   'List of homeschooling programmes',
#   'Media coverage of the COVID-19 pandemic',
#   'Micro-schooling',
#   'MySejahtera',
#   'NZ COVID Tracer',
#   'NZ Pass Verifier',
#   'SafeEntry',
#   'SafePass',
#   'StaySafe.ph',
#   'TraceTogether',
#   'Umbrella school',
#   'Unschooling'],
#  ['Academic integrity',
#   'BlueTrace',
#   'COVID-19 Contact-Confirming Application',
#   'COVIDSafe',
#   'COVID Tracker Ireland',
#   'CareFIJI',
#   'Child',
#   'Child care',
#   'Coronavirus Australia',
#   'Digital divide',
#   'Digital learning',
#   'Digital media in education',
#   'Early childhood education',
#   'F visa',
#   'Female education',
#   'Field trip',
#   'Homeschooling during the COVID-19 pandemic',
#   'Human rights issues related to the COVID-19 pandemic',
#   'Impact of the COVID-19 pandemic on African communities',
#   'Impact of the COVID-19 pandemic on children',
#   'Impact of the COVID-19 pandemic on domestic violence',
#   'Impact of the COVID-19 pandemic on female education',
#   'Impact of the COVID-19 pandemic on the military',
#   'Informal education',
#   'Instructional television',
#   'International Standard Classification of Education',
#   'Internet',
#   'Kindergarten',
#   'K–12',
#   'Learning crisis',
#   'M-1 visa',
#   'Media coverage of the COVID-19 pandemic',
#   'Ministry of Education and Culture (Indonesia)',
#   'Ministry of Education and Science (Russia)',
#   'MySejahtera',
#   'NZ COVID Tracer',
#   'NZ Pass Verifier',
#   'National Center for Education Statistics',
#   'Open educational resources',
#   'Physical education',
#   'Postgraduate education',
#   'Primary school',
#   'Public domain',
#   'SafeEntry',
#   'SafePass',
#   'Secondary education',
#   'Secondary school',
#   'Secretariat of Public Education (Mexico)',
#   'Social issue',
#   'StaySafe.ph',
#   'Tertiary education',
#   'TraceTogether',
#   'United States Department of Education',
#   'Vocational education'],
#  ['Comprehensive sex education',
#   'Digital divide',
#   'Domestic violence',
#   'Female education',
#   'Gender equality',
#   'Girl',
#   'Impact of the COVID-19 pandemic on domestic violence',
#   'Impact of the COVID-19 pandemic on education',
#   'Impact of the COVID-19 pandemic on the military',
#   'Media coverage of the COVID-19 pandemic'],
#  ['21st century skills',
#   'Adult education',
#   'Age of Enlightenment',
#   'Alternative education',
#   'Autodidacticism',
#   'Bilingual education',
#   'Carolingian schools',
#   'Civil service',
#   'Commission of National Education',
#   'Compulsory education',
#   'Computer science education',
#   'Confucius',
#   'Continuing education',
#   'Early childhood education',
#   'Education economics',
#   'Education in Antigua and Barbuda',
#   'Education in Dominica',
#   'Education in Georgia (country)',
#   'Education in Grenada',
#   'Education in Guinea-Bissau',
#   'Education in Niue',
#   'Education in Saint Kitts and Nevis',
#   'Education in Saint Lucia',
#   'Education in Saint Vincent and the Grenadines',
#   'Education in Tonga',
#   'Education in the Cayman Islands',
#   'Education in the Cook Islands',
#   'Education in the Falkland Islands',
#   'Education in the Federated States of Micronesia',
#   'Education policy',
#   'Education reform',
#   'Educational aims and objectives',
#   'Educational anthropology',
#   'Educational assessment',
#   'Educational evaluation',
#   'Educational leadership',
#   'Educational research',
#   'Educational stage',
#   'Educational technology',
#   'Environmental education',
#   'Friedrich Schleiermacher',
#   'Further education',
#   'Gifted education',
#   'Higher education',
#   'Imperial examination',
#   'Index of education articles',
#   'Kindergarten',
#   'List of education by subject',
#   'Middle school',
#   'Military education and training',
#   'Ministry of National Education (Turkey)',
#   'Outline of education',
#   'Peace education',
#   'Pedagogy',
#   'Philosophy of education',
#   'Physical education',
#   'Physics education',
#   'Politics in education',
#   'Postgraduate education',
#   'Primary school',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Secular education',
#   'Sociology of education',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'Values education',
#   'Vocational education'],
#  [],
#  ['Public domain'],
#  ['Public domain',
#   'Settlement and community houses in the United States',
#   'Settlement movement'],
#  ['Pedagogy'],
#  ['Active learning',
#   'Bertrand Russell',
#   'Bilingual education',
#   'Blended learning',
#   'Block scheduling',
#   'Charter school',
#   'Bureaucracy',
#   'Class size',
#   'Classical education movement',
#   'Cognitive load',
#   'Compulsory education',
#   'Constructivism (philosophy of education)',
#   'Democracy',
#   'Dropping out',
#   'Education policy',
#   'Educational program',
#   'Excellence and equity',
#   'Experiential education',
#   'Female education',
#   'Higher Education Act of 1965',
#   'Higher education bubble in the United States',
#   'Humanistic education',
#   'Inclusion (education)',
#   'Institute of Education Sciences',
#   'Institution',
#   'Internet',
#   'Inventive spelling',
#   'Issues in higher education in the United States',
#   'Jean-Jacques Rousseau',
#   'Kindergarten',
#   'K–12',
#   'Learning crisis',
#   'Learning standards',
#   'Lecture',
#   'Mainstreaming (education)',
#   'Merit pay',
#   'Montessori education',
#   'Multiculturalism',
#   'Outcome-based education',
#   'Pedagogy',
#   'Phonics',
#   'Populism',
#   'Progressive education',
#   'School choice',
#   'School prayer',
#   'School voucher',
#   'Small schools movement',
#   'Sociology of education',
#   'Standard algorithms',
#   'Standardized test',
#   'State school',
#   'Student-centered learning',
#   'Student rights',
#   'Textbook',
#   'Tracking (education)',
#   'Traditional education',
#   'United States Department of Education',
#   'University reform',
#   'Vocational school',
#   'World War II',
#   'World economy'],
#  ['A Vindication of the Rights of Woman',
#   'General will',
#   'Jean-Jacques Rousseau',
#   'Johann Wolfgang von Goethe',
#   'Montessori education',
#   'Parenting',
#   'Pedagogy',
#   'Philosophy of education',
#   'Political philosophy',
#   'Project Gutenberg',
#   'Voltaire'],
#  ['Bilingual education',
#   'Bologna Process',
#   'Content and language integrated learning',
#   'Definitions of education',
#   'English language',
#   'Higher education',
#   'Internationalization of higher education',
#   'Internet',
#   'Medium of instruction',
#   'Public sector',
#   'Secondary education',
#   'World War II'],
#  ['A Vindication of the Rights of Woman',
#   'Commission of National Education',
#   'Computer science education',
#   'Early childhood education',
#   'Education reform',
#   'Educational evaluation',
#   'Educational research',
#   'Educational technology',
#   'Electronic assessment',
#   'Female education in STEM',
#   'Feminist political theory',
#   'Feminist views on the Oedipus complex',
#   'Free education',
#   'Gender equality',
#   'Gender inequality in curricula',
#   'Gender mainstreaming',
#   'Gender mainstreaming in teacher education policy',
#   'Global feminism',
#   'History of education',
#   'Honor killing',
#   'International development',
#   'International education',
#   'Internet',
#   'M-learning',
#   'Materialist feminism',
#   'Mixed-sex education',
#   'Multiculturalism',
#   'Natural rights and legal rights',
#   'Patriarchy',
#   'Philosophy of education',
#   'Poverty reduction',
#   'Reactionary feminism',
#   'Reproductive justice',
#   'Right to education',
#   'Secondary education',
#   'Secondary school',
#   'Special education',
#   'Technology education',
#   'Tertiary education',
#   'Visual arts education',
#   'Vocational education',
#   'War on women'],
#  ['Curriculum',
#   'Early childhood education',
#   'Gender equality',
#   'Higher education',
#   'Programme for International Student Assessment',
#   'Teaching method',
#   'Trends in International Mathematics and Science Study'],
#  ['History of education', 'Kindergarten', 'Right to education'],
#  [],
#  ['Deaf education'],
#  ['International law'],
#  ['Social capital'],
#  ['History of education', 'Informal education', 'Pedagogy'],
#  ['Anti-intellectualism',
#   'Asian quota',
#   'Democide',
#   'Discrimination in education',
#   'Diversity training',
#   'Dreyfus affair',
#   'Elitism',
#   'Ethnic penalty',
#   'Fear of children',
#   'Ghetto benches',
#   'Hate crime',
#   'Higher education',
#   'Human rights',
#   'Institutional discrimination',
#   'Kinder der Landstrasse',
#   'Lynching',
#   'Multiculturalism',
#   'Nonviolence',
#   'Numerus clausus',
#   'Philosemitism',
#   'Polyculturalism',
#   'Pregnancy discrimination',
#   'Prisoner abuse',
#   'Religious violence',
#   'Self-determination',
#   'Social exclusion',
#   'Speciesism',
#   'State atheism',
#   'Well poisoning',
#   'White power music',
#   'Wife selling',
#   'Woke'],
#  ['Jews', 'Numerus clausus', 'Oligarchy', 'Plutocracy'],
#  ['Female education'],
#  ['Adult education', 'John Milton'],
#  ['Anti-intellectualism',
#   'Asian quota',
#   'Democide',
#   'Discrimination in education',
#   'Diversity training',
#   'Dog whistle (politics)',
#   'Elitism',
#   'Ethnic penalty',
#   'Fear of children',
#   'Ghetto benches',
#   'Hate crime',
#   'Human rights',
#   'Institutional discrimination',
#   'Jewish quota',
#   'Kinder der Landstrasse',
#   'Lynching',
#   'Multiculturalism',
#   'Nonviolence',
#   'Political repression',
#   'Polyculturalism',
#   'Pregnancy discrimination',
#   'Prisoner abuse',
#   'Religious violence',
#   'Self-determination',
#   'Social exclusion',
#   'Speciesism',
#   'State atheism',
#   'Student',
#   'University',
#   'Vichy France',
#   'White power music',
#   'Wife selling',
#   'Woke'],
#  ['Alternative school',
#   'Amish',
#   'Charter school',
#   'College',
#   'Compensatory education',
#   'Compulsory education',
#   'Continuing education',
#   'Day school',
#   'Democratic education',
#   'Department of Bantu Education',
#   'Early childhood education',
#   'Educational stage',
#   'Form (education)',
#   'Free education',
#   'Free school movement',
#   'Further education',
#   'Gifted education',
#   'Hedge school',
#   'Higher education',
#   'Indigenous peoples',
#   'Infant school',
#   'Junior school',
#   'Kindergarten',
#   'K–12',
#   'Micro-schooling',
#   'Middle school',
#   'Montessori education',
#   'Moonshine',
#   'Pre-kindergarten',
#   'Primary school',
#   'Private university',
#   'Progressive education',
#   'Secondary education',
#   'Secondary school',
#   'Special education',
#   'State school',
#   'Sudbury school',
#   'Technical school',
#   'Tertiary education',
#   'Two-room school',
#   'University',
#   'Vigilantism',
#   'Vocational school',
#   'Vocational university',
#   'World War II'],
#  ['Hedge school'],
#  ['Apprenticeship', 'Compulsory education', 'World War I', 'World War II'],
#  [],
#  [],
#  ['Special education'],
#  ['College Settlements Association',
#   'Development economics',
#   'Global city',
#   'Naturalization',
#   'Public domain',
#   'Public policy',
#   'Settlement movement',
#   'Social work',
#   'Transferable development rights'],
#  ['Development economics',
#   'Global city',
#   'Higher education',
#   'Poverty reduction',
#   'Public policy',
#   'Settlement school',
#   'Social movement',
#   'Social work',
#   'Stanislav Shatsky',
#   'Transferable development rights'],
#  ['Adult education',
#   'Dyslexia',
#   'Environmental education',
#   'Middle school',
#   'Settlement movement'],
#  ['Public domain', 'Secondary education'],
#  ['National Library of Australia', 'Project Gutenberg', 'Voltaire'],
#  ['Anarchism',
#   'Frankfurt School',
#   'Pedagogy',
#   'Philosophy of religion',
#   'Political philosophy',
#   'Social contract',
#   'Socratic questioning',
#   'Transactionalism'],
#  ['Female education', 'Vocational school'],
#  ['Kindergarten',
#   'Primary school',
#   'Secondary education',
#   'Secondary school',
#   'Town hall'],
#  ['Animal rights',
#   'Bell hooks',
#   'David Hume',
#   'Day school',
#   'Gender equality',
#   'George Eliot',
#   'Jean-Jacques Rousseau',
#   'Judith Butler',
#   'Political philosophy',
#   'Project Gutenberg',
#   'Republicanism',
#   'Virginia Woolf'],
#  ['Blended learning',
#   'Fle3',
#   'Internet',
#   'Learning management system',
#   'Machine learning',
#   'Massive open online course',
#   'Open University',
#   'Synchronous conferencing',
#   'Television',
#   'Virtual learning environment',
#   'Web conferencing'],
#  ['Age of Enlightenment',
#   'Compulsory education',
#   'One-room school',
#   'Primary school',
#   'Secondary education'],
#  ['Divine right of kings',
#   'Imperial examination',
#   'John Donne',
#   'Project Gutenberg'],
#  ['Komsomolskaya Pravda', 'RIA Novosti'],
#  ['Culture of Peace'],
#  ['National High School Mock Trial Championship'],
#  [],
#  ['Department of Education (Philippines)'],
#  ['Pax Romana'],
#  [],
#  [],
#  ['Australian Curriculum',
#   'Australian Curriculum',
#   'Department of Education (Australia)',
#   'Tertiary education fees in Australia'],
#  ['National Liaison Committee for International Students in Australia'],
#  [],
#  ['Federation of American Scientists',
#   'Impact of the COVID-19 pandemic on education',
#   'M-1 visa'],
#  ['International student'],
#  ['Multiculturalism'],
#  ['International student'],
#  ['Brethren Colleges Abroad',
#   'F visa',
#   'International Student Identity Card',
#   'International education',
#   'International students in Canada',
#   'M-1 visa',
#   'Pakistani students abroad',
#   'School uniform',
#   'Tertiary education'],
#  ['International student'],
#  [],
#  ['International student'],
#  ['Postgraduate education', 'Student financial aid'],
#  ['College',
#   'Full-time equivalent',
#   'Primary school',
#   'Scholarship',
#   'Secondary school'],
#  ['Ministry of the Treasury'],
#  ['International student', 'Technical school', 'Vocational school'],
#  [],
#  ['English language'],
#  ['Non-governmental organization', 'Secondary school', 'World War II'],
#  ['International student'],
#  ['International student',
#   'Ministry of Federal Education and Professional Training'],
#  [],
#  ['Ministry of Education (New Zealand)'],
#  ...]

# %%
df['Links'] = links_clean

# %%
# Creating network

col_from = [] # Link from page...
col_to = []   # ...to page.

for index, row in df.iterrows(): # iterating over rows
    for e in row['Links']:
        col_from.append(row['Page'])
        col_to.append(e)

print(len(col_from))
print(len(col_to))
# Out:
# 165959
# 165959

# %%
# Saving dataframe

df_network = pd.DataFrame()
df_network['from'] = col_from
df_network['to'] = col_to

df_network
# Out:
#                                    from                     to
# 0                            Field trip             Curriculum
# 1                            Field trip  Experiential learning
# 2                            Field trip      Government agency
# 3                            Field trip                Lecture
# 4                            Field trip          Middle school
# ...                                 ...                    ...
# 165954            The Unprocessed Child            Unschooling
# 165955               Virtual visitation          Child custody
# 165956               Virtual visitation              Parenting
# 165957  Where Are We Going, Dad? (film)              Parenting
# 165958            Wisdom of Our Fathers              Parenting
#
# [165959 rows x 2 columns]

# %%
# Creating networkx graph
DG = nx.DiGraph()

# Adding nodes
for index,row in df.iterrows():
    # Adding node and attributes
    DG.add_node(row['Page'], category=row['Category'], score=row['Score'])

# %%
# Adding edges
for index, row in df_network.iterrows():
    DG.add_edge(row['from'],row['to'])

# %%
print("Total number of nodes: ", int(DG.number_of_nodes()))
print("Total number of edges: ", int(DG.number_of_edges()))
# Out:
# Total number of nodes:  14928
# Total number of edges:  165882

# %%
density = nx.density(DG)
print("Network density:", density)
# Out:
# Network density: 0.0007444321205644533

# %%
# Error computing diagram: the graph is not strongly connected

# diameter = nx.diameter(DG)
# print("Diameter:", diameter)

# %% [markdown]
# # Getting largest connected component

# %%
# Taking largest connected component

gcc = sorted(nx.weakly_connected_components(DG), key=len, reverse=True) # giant connected component
DG = DG.subgraph(gcc[0])

# %%
print("Total number of nodes: ", int(DG.number_of_nodes()))
print("Total number of edges: ", int(DG.number_of_edges()))
# Out:
# Total number of nodes:  12762
# Total number of edges:  165568

# %% [markdown]
# # Exporting

# %%
# Exporting Gephi

nx.write_gexf(DG,'./data/network_connected.gexf')

# %%
# Checking export

DG = nx.read_gexf('./data/network_connected.gexf')

print("Total number of nodes: ", int(DG.number_of_nodes()))
print("Total number of edges: ", int(DG.number_of_edges()))
# Out:
# Total number of nodes:  12762
# Total number of edges:  165568
